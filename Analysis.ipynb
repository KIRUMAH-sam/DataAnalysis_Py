# %%
#  Here we will Load the Iris dataset, import the libraries, and explore the dataset.
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Set seaborn style
sns.set(style="whitegrid")

try:
    # Option 1: Load Iris dataset from sklearn
    from sklearn.datasets import load_iris
    iris = load_iris(as_frame=True)
    df = iris.frame  # Contains features + target

    # Rename target column for clarity
    df = df.rename(columns={"target": "species"})
    df["species"] = df["species"].map(dict(enumerate(iris.target_names)))

except FileNotFoundError:
    print("Error: Dataset file not found. Please check the path.")
except Exception as e:
    print("Unexpected error while loading dataset:", e)

# Display first rows
print("\nFirst 5 rows of the dataset:")
print(df.head())

# Check info and missing values
print("\nDataset Info:")
print(df.info())

print("\nMissing Values Check:")
print(df.isnull().sum())

# No missing values in Iris dataset, but general code:
df = df.dropna()  # or df.fillna(method='ffill')
# Out:
# First 5 rows of the dataset:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#   species
# 0  setosa
# 1  setosa
# 2  setosa
# 3  setosa
# 4  setosa
#
# Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  150 non-null    float64
#  1   sepal width (cm)   150 non-null    float64
#  2   petal length (cm)  150 non-null    float64
#  3   petal width (cm)   150 non-null    float64
# ...

# %%
# In this second cell we will do some basic data analysis
# Basic statistics
print("\nSummary Statistics:")
print(df.describe())

# Grouping by categorical column 'species'
grouped = df.groupby("species").mean()
print("\nMean values per species:")
print(grouped)

# Example finding
print("\nObservation: Setosa tends to have smaller sepal and petal measurements compared to Virginica and Versicolor.")
# Out:
# Summary Statistics:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)
# count        150.000000
# mean           1.199333
# std            0.762238
# min            0.100000
# 25%            0.300000
# 50%            1.300000
# 75%            1.800000
# max            2.500000
#
# Mean values per species:
#             sepal length (cm)  sepal width (cm)  petal length (cm)  \
# species
# ...

# %%
# Data Visualization of the dataset, bar and line charts, histogram and scatter plot
# 1. Line Chart (example: petal length across dataset index)
plt.figure(figsize=(8,5))
plt.plot(df.index, df["petal length (cm)"], label="Petal Length")
plt.title("Line Chart of Petal Length across Observations")
plt.xlabel("Index")
plt.ylabel("Petal Length (cm)")
plt.legend()
plt.show()

# 2. Bar Chart: Average petal length per species
plt.figure(figsize=(8,5))
sns.barplot(x="species", y="petal length (cm)", data=df, estimator="mean", ci=None)
plt.title("Average Petal Length by Species")
plt.xlabel("Species")
plt.ylabel("Average Petal Length (cm)")
plt.show()

# 3. Histogram: Distribution of sepal length
plt.figure(figsize=(8,5))
plt.hist(df["sepal length (cm)"], bins=15, color="skyblue", edgecolor="black")
plt.title("Histogram of Sepal Length")
plt.xlabel("Sepal Length (cm)")
plt.ylabel("Frequency")
plt.show()

# 4. Scatter Plot: Sepal length vs Petal length
plt.figure(figsize=(8,5))
sns.scatterplot(x="sepal length (cm)", y="petal length (cm)", hue="species", data=df)
plt.title("Sepal Length vs Petal Length by Species")
plt.xlabel("Sepal Length (cm)")
plt.ylabel("Petal Length (cm)")
plt.legend(title="Species")
plt.show()
# Out:
# C:\Users\Skiru\AppData\Local\Temp\ipykernel_1472\4233642309.py:13: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x="species", y="petal length (cm)", data=df, estimator="mean", ci=None)

# %%
# Findings / Observations
"""
Findings:
1. Iris Setosa has the smallest petals and sepals compared to the other species.
2. Petal length is a strong differentiator between Setosa and the other two species.
3. The distribution of sepal length shows clustering around 5-6 cm.
4. Scatter plots reveal clear separation between Setosa and the rest,
   while Versicolor and Virginica overlap slightly.
"""
# Out:
# '\nFindings:\n1. Iris Setosa has the smallest petals and sepals compared to the other species.\n2. Petal length is a strong differentiator between Setosa and the other two species.\n3. The distribution of sepal length shows clustering around 5-6 cm.\n4. Scatter plots reveal clear separation between Setosa and the rest,\n   while Versicolor and Virginica overlap slightly.\n'
